# %% [markdown]
# ### Assignment
# https://www.lizmotors.com/internship-coding-assignment2024/
# + In this assignment, we would like you to demonstrate how you would approach the task of gathering the required information for the case study using Python programming.
# + Specifically, we want you to write a Python script that searches the internet for information related to __Canoo__, a __publicly traded company__ listed on __NASDAQ__ (ticker symbol: __GOEV__).
# + Your script should retrieve data from various online sources and store it in a CSV file for further analysis.
# + Here are the specific tasks you should perform:
#
#     1. Identify the __industry in which Canoo operates__, __along with its size__, __growth rate__, __trends__, and __key players__.
#     1. __Analyze Canoo's main competitors__, including their __market share__, __products or services offered__, __pricing strategies__, and __marketing efforts__.
#     1. Identify __key trends in the market__, including changes in __consumer behavior__, __technological advancements__, and __shifts in the competitive landscape__.
#     1. Gather information on __Canoo's financial performance__, including its __revenue__, __profit margins__, __return on investment__, and __expense structure__.

# %% [markdown]
# #### Submission
# In your submission, please include the following:
# 1. Your Name, contact details and email address
# 1. A brief summary of the steps you took to complete the task, including any challenges you faced and how you overcame them.
# 1. A link to a GitHub repository containing your Python script and any necessary dependencies.
# 1. A sample output of the data retrieved from the internet, stored in a CSV file or other suitable format.

# %% [markdown]
# ### Import Library

# %%
import requests
from bs4 import BeautifulSoup
import yfinance as yf
import pandas as pd
import csv

# %% [markdown]
# ## Data Collection

# %%
def fetch_company_info(ticker_symbol):
    try:
        company = yf.Ticker(ticker_symbol)
        company_info = company.info
        return company_info
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

def save_to_csv(data, filename):
    try:
        df = pd.DataFrame(data)
        df.to_csv(filename, index=False)
        print(f"Data saved successfully to {filename}")

    except Exception as e:
        print(f"An error occurred while saving to CSV: {str(e)}")

if __name__ == "__main__":
    ticker_symbol = "GOEV"
    company_info = fetch_company_info(ticker_symbol)
    print(type(company_info))
    if company_info:
        print(f"Information about {ticker_symbol}:")
        for key, value in company_info.items():
            print(f"{key}: {value}")
            
        data = fetch_company_info(ticker_symbol)
        if data:
            save_to_csv(data, "cancoo_detail.csv")
    else:
        print(f"Failed to retrieve information about {ticker_symbol}")
# Out:
# <class 'dict'>
# Information about GOEV:
# address1: 19951 Mariner Avenue
# city: Torrance
# state: CA
# zip: 90503
# country: United States
# phone: 424 271 2144
# website: https://www.canoo.com
# industry: Auto Manufacturers
# industryKey: auto-manufacturers
# industryDisp: Auto Manufacturers
# sector: Consumer Cyclical
# sectorKey: consumer-cyclical
# sectorDisp: Consumer Cyclical
# longBusinessSummary: Canoo Inc., a mobility technology company, designs, engineers, develops, and manufactures electric vehicles for commercial and consumer markets in the United States. The company offers lifestyle delivery vehicles, lifestyle vehicles, multi-purpose delivery vehicles, and pickups. It also provides multi-purpose platform architecture is a self-contained, fully functional rolling chassis that directly houses the critical components for operation of an EV. Canoo Inc. was founded in 2017 and is headquartered in Torrance, California.
# fullTimeEmployees: 812
# ...

# %%
# Set the option to display all columns
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("cancoo_detail.csv")
data
# Out:
#                address1      city state    zip        country         phone  \
# 0  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 1  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 2  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 3  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 4  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 5  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 6  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 7  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
#
#                  website            industry         industryKey  \
# 0  https://www.canoo.com  Auto Manufacturers  auto-manufacturers
# 1  https://www.canoo.com  Auto Manufacturers  auto-manufacturers
# 2  https://www.canoo.com  Auto Manufacturers  auto-manufacturers
# ...

# %%
for d in data.companyOfficers:
    print(d)
# Out:
# {'maxAge': 1, 'name': 'Mr. Anthony  Aquila', 'age': 58, 'title': 'Executive Chairman & CEO', 'yearBorn': 1965, 'fiscalYear': 2022, 'totalPay': 500000, 'exercisedValue': 0, 'unexercisedValue': 0}
# {'maxAge': 1, 'name': 'Mr. Ramesh  Murthy', 'age': 44, 'title': 'Senior VP of Finance & Chief Accounting Officer', 'yearBorn': 1979, 'fiscalYear': 2022, 'totalPay': 350000, 'exercisedValue': 0, 'unexercisedValue': 0}
# {'maxAge': 1, 'name': 'Mr. Sohel  Merchant', 'title': 'Founder & CTO', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}
# {'maxAge': 1, 'name': 'Mr. Hector  Ruiz', 'age': 42, 'title': 'General Counsel & Corporate Secretary', 'yearBorn': 1981, 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}
# {'maxAge': 1, 'name': 'Agnes  Gomes-Koizumi', 'title': 'Vice President of Communications', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}
# ...

# %%
def fetch_company_stock_history(ticker_symbol):
    try:
        canoo_stock = yf.Ticker(ticker_symbol)
        data = canoo_stock.history(period="1d", start="2017-01-01", end="2025-01-01")
        return data

    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

def save_to_csv(data, filename):
    try:
        #df = pd.DataFrame(data)
        # Convert the index to TimedeltaIndex using pd.to_timedelta
        #data.index = pd.to_datetime(data.index )
        data['data'] = pd.to_datetime(data.index)
        data.to_csv(filename, index=False)
        print(f"Data saved successfully to {filename}")

    except Exception as e:
        print(f"An error occurred while saving to CSV: {str(e)}")

if __name__ == "__main__":
    ticker_symbol = "GOEV"
    stock_hostory = fetch_company_stock_history(ticker_symbol)
    
    history = fetch_company_stock_history(ticker_symbol)
    save_to_csv(history, "cancoo_Stock_history.csv")
# Out:
# /home/vishal/.local/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# /home/vishal/.local/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# Data saved successfully to cancoo_Stock_history.csv

# %%
stock_history = pd.read_csv("cancoo_Stock_history.csv")
stock_history
# Out:
#        Open     High    Low  Close    Volume  Dividends  Stock Splits  \
# 0     9.840   9.8500  9.820  9.840    770500        0.0           0.0
# 1     9.890   9.8900  9.830  9.840    138100        0.0           0.0
# 2     9.870  10.3400  9.840  9.840     21200        0.0           0.0
# 3     9.840   9.8400  9.840  9.840       100        0.0           0.0
# 4     9.810   9.8100  9.810  9.810       100        0.0           0.0
# ...     ...      ...    ...    ...       ...        ...           ...
# 1215  0.150   0.1510  0.141  0.145  59109800        0.0           0.0
# 1216  0.147   0.1480  0.142  0.142  51865300        0.0           0.0
# 1217  0.145   0.1550  0.142  0.146  72059100        0.0           0.0
# 1218  0.145   0.1490  0.139  0.141  71334500        0.0           0.0
# 1219  0.145   0.1431  0.132  0.134  33096182        0.0           0.0
#
#                            data
# 0     2019-04-16 00:00:00-04:00
# 1     2019-04-17 00:00:00-04:00
# ...

# %%
def get_real_time_data(ticker):
    stock = yf.Ticker(ticker)
    real_time_data = stock.info
    return real_time_data

# Example usage:
ticker = "GOEV"
real_time_data = get_real_time_data(ticker)
print("Real-Time Data for", ticker)
print(real_time_data)
# Out:
# Real-Time Data for GOEV
# ...

# %%
def get_dividend_info(ticker):
    stock = yf.Ticker(ticker)
    dividend_info = stock.dividends
    return dividend_info

# Example usage:
ticker = "GOEV"
dividend_info = get_dividend_info(ticker)
print("Dividend Information for", ticker)
print(dividend_info)
# Out:
# Dividend Information for GOEV
# Series([], Name: Dividends, dtype: float64)
# /home/vishal/.local/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
def get_recommendations(ticker):
    stock = yf.Ticker(ticker)
    recommendations = stock.recommendations
    return recommendations

# Example usage:
ticker = "GOEV"
recommendations = get_recommendations(ticker)
print("Recommendations for", ticker)
print(recommendations)
# Out:
# Recommendations for GOEV
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          0    0     0     0           0
# 1    -1m          2    3     1     0           0
# 2    -2m          1    3     1     0           0
# 3    -3m          0    0     0     0           0

# %%
import yfinance as yf

def get_options_chain(ticker, expiration_date=None):
    stock = yf.Ticker(ticker)
    options_chain = stock.option_chain(expiration_date)
    return options_chain

# Example usage:
ticker = "GOEV"
expiration_date = "2024-03-01"  # Provide a specific expiration date or leave it as None for the nearest expiration
options_chain = get_options_chain(ticker, expiration_date)
print("Options Chain for", ticker, "on", expiration_date)
print(options_chain)
# Out:
# Options Chain for GOEV on 2024-03-01
# Options(calls=        contractSymbol             lastTradeDate  strike  lastPrice  bid  \
# 0  GOEV240301C00000500 2024-02-15 14:30:13+00:00     0.5       0.01  0.0
# 1  GOEV240301C00001000 2024-02-12 18:11:20+00:00     1.0       0.01  0.0
# 2  GOEV240301C00001500 2024-01-19 14:30:13+00:00     1.5       0.04  0.0
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  0.01     0.0            0.0       1          2067           5.000004
# 1  0.01     0.0            0.0       2            89           6.500002
# 2  0.02     0.0            0.0       5             5           8.250005
#
#    inTheMoney contractSize currency
# 0       False      REGULAR      USD
# 1       False      REGULAR      USD
# 2       False      REGULAR      USD  , puts=        contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0  GOEV240301P00000500 2024-02-13 17:30:04+00:00     0.5       0.38  0.33
# ...

# %% [markdown]
# #### 1. Identify the <span style="color: #1f77b4">__industry in which Canoo operates__</span>, <span style="color: #9467bd">__along with its size__</span>, <span style="color: #17becf">__growth rate__</span>, <span style="color: #d62728">__trends__</span>, and <span style="color: #2ca02c">__key players__</span>.

# %%
data
# Out:
#                address1      city state    zip        country         phone  \
# 0  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 1  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 2  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 3  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 4  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 5  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 6  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 7  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
#
#                  website            industry         industryKey  \
# 0  https://www.canoo.com  Auto Manufacturers  auto-manufacturers
# 1  https://www.canoo.com  Auto Manufacturers  auto-manufacturers
# 2  https://www.canoo.com  Auto Manufacturers  auto-manufacturers
# ...

# %%
# Industry in which Canco Operates
ind = data.industry.unique()[0]

print("Industry in which Canco Operates: ", ind)
# Out:
# Industry in which Canco Operates:  Auto Manufacturers

# %%
#Size of the company
company_size = data['fullTimeEmployees'].iloc[0]

# Print the company size
print(f"The company size is: {company_size} employees")
# Out:
# The company size is: 812 employees

# %% [markdown]
# > The "52WeekChange" for Canoo stock tells us how much its price has changed over the last year. If it's positive, the stock has gone up; if negative, it's gone down. This helps us understand how much the stock's value has fluctuated recently and gives insights into its overall trend and volatility.
#
# > A "52WeekChange" value of -0.836994 means that the stock has experienced a negative change of approximately 83.70% over the past 52 weeks. This indicates a significant decline in the stock's value during that one-year period. Investors interpret this negative change as a decrease in the stock's price compared to its value a year ago. It reflects a challenging performance or a downward trend in the stock over the specified timeframe.

# %%
# Growth Rate
growth_rate = data['52WeekChange'][0]

print("Negative Growth_rate : ", growth_rate*100)
# Out:
# Negative Growth_rate :  -83.699423

# %%
stock_history
# Out:
#        Open     High    Low  Close    Volume  Dividends  Stock Splits  \
# 0     9.840   9.8500  9.820  9.840    770500        0.0           0.0
# 1     9.890   9.8900  9.830  9.840    138100        0.0           0.0
# 2     9.870  10.3400  9.840  9.840     21200        0.0           0.0
# 3     9.840   9.8400  9.840  9.840       100        0.0           0.0
# 4     9.810   9.8100  9.810  9.810       100        0.0           0.0
# ...     ...      ...    ...    ...       ...        ...           ...
# 1215  0.150   0.1510  0.141  0.145  59109800        0.0           0.0
# 1216  0.147   0.1480  0.142  0.142  51865300        0.0           0.0
# 1217  0.145   0.1550  0.142  0.146  72059100        0.0           0.0
# 1218  0.145   0.1490  0.139  0.141  71334500        0.0           0.0
# 1219  0.145   0.1431  0.132  0.134  33096182        0.0           0.0
#
#                            data
# 0     2019-04-16 00:00:00-04:00
# 1     2019-04-17 00:00:00-04:00
# ...

# %%
import matplotlib.pyplot as plt

# Assuming 'stock_history' is your DataFrame
stock_history['Date'] = pd.to_datetime(stock_history['data'])

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(stock_history['Date'], stock_history['Open'], label='Open Price', marker='+', )
plt.plot(stock_history['Date'], stock_history['Close'], label='Close Price', marker='+')
plt.title('Stock Open and Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_2550/1281595850.py:4: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   stock_history['Date'] = pd.to_datetime(stock_history['data'])

# %% [markdown]
# #### 2. <span style="color: #ff7f0e">__Analyze Canoo's main competitors__</span>, including their <span style="color: #8c564b">__market share__</span>, <span style="color: #e377c2">__products or services offered__</span>, <span style="color: #7f7f7f">__pricing strategies__</span>, and <span style="color: #bcbd22">__marketing efforts__</span>.

# %%
content = """<br><br><table class="table outputtable" style="width:98%;"><tr style="text-align:left"><th style="width:200px">Company</th><th style="width:150px;">Headquarters</th><th style="text-align:right;width:220px">Revenue ($ MM)</th></tr><tr><td><a href="/company/tesla-paloalto-ca/">TESLA</a></td><td>Palo Alto, CA</td><td style="text-align:right"><span style="float:right"><span class="revwidth" style="width:50px;">100</span><span class="revmainder" style="width:0px;">&nbsp;</span></span></td></tr><tr><td><a href="/company/generalmotors-detroit-mi/">GENERAL MOTORS HOLDINGS</a></td><td>Detroit, MI</td><td style="text-align:right"><span style="float:right"><span class="revwidth" style="width:49.5px;">99</span><span class="revmainder" style="width:0.5px;">&nbsp;</span></span></td></tr><tr><td><a href="/company/uawfordvoluntaryemployeesbe-detroit-mi/">UAW-FORD VOLUNTARY EMPLOYEES BE</a></td><td>Detroit, MI</td><td style="text-align:right"><span style="float:right"><span class="revwidth" style="width:31.5px;">63</span><span class="revmainder" style="width:18.5px;">&nbsp;</span></span></td></tr><tr><td><a href="/company/fcaus-auburnhills-mi/">FCA US</a></td><td>Auburn Hills, MI</td><td style="text-align:right"><span style="float:right"><span class="revwidth" style="width:29.5px;">59</span><span class="revmainder" style="width:20.5px;">&nbsp;</span></span></td></tr><tr><td><a href="/company/americanhondamotor-marysville-oh/">AMERICAN HONDA MOTOR</a></td><td>Marysville, OH</td><td style="text-align:right"><span style="float:right"><span class="revwidth" style="width:22.5px;">45</span><span class="revmainder" style="width:27.5px;">&nbsp;</span></span></td></tr><tr><td><a href="/company/northropgrummansystems-fairfax-va/">NORTHROP GRUMMAN SYSTEMS</a></td><td>Fairfax, VA</td><td style="text-align:right"><span style="float:right"><span class="revwidth" style="width:21.5px;">43</span><span class="revmainder" style="width:28.5px;">&nbsp;</span></span></td></tr><tr><td><a href="/company/eaton-cleveland-oh/">EATON</a></td><td>Cleveland, OH</td><td style="text-align:right"><span style="float:right"><span class="revwidth" style="width:19.5px;">39</span><span class="revmainder" style="width:30.5px;">&nbsp;</span></span> </td></tr><tr><td><a href="/company/boeing-seattle-wa/">BOEING</a></td><td>Seattle, WA</td><td style="text-align:right"><span style="float:right"><span class="revwidth" style="width:17.5px;">35</span><span class="revmainder" style="width:32.5px;">&nbsp;</span></span></td></tr></table>"""

# %%
# Assuming content is your HTML content
df1 = pd.read_html(content)[0]  # Read HTML content into df1

# Read competitors_info.csv into df2
df2 = pd.read_csv("competitors_info.csv")

# Concatenate df1 and df2
result = pd.concat([df1, df2])
result
# Out:
# /tmp/ipykernel_2550/3378275761.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_html(content)[0]  # Read HTML content into df1
#                            Company      Headquarters  Revenue ($ MM)  \
# 0                            TESLA     Palo Alto, CA           100.0
# 1          GENERAL MOTORS HOLDINGS       Detroit, MI            99.0
# 2  UAW-FORD VOLUNTARY EMPLOYEES BE       Detroit, MI            63.0
# 3                           FCA US  Auburn Hills, MI            59.0
# 4             AMERICAN HONDA MOTOR    Marysville, OH            45.0
# 5         NORTHROP GRUMMAN SYSTEMS       Fairfax, VA            43.0
# 6                            EATON     Cleveland, OH            39.0
# 7                           BOEING       Seattle, WA            35.0
# 0                            Tesla               NaN             NaN
# ...

# %%
for col in data.columns.to_list():
    print(col)
# Out:
# address1
# city
# state
# zip
# country
# phone
# website
# industry
# industryKey
# industryDisp
# sector
# sectorKey
# sectorDisp
# longBusinessSummary
# fullTimeEmployees
# companyOfficers
# auditRisk
# boardRisk
# compensationRisk
# shareHolderRightsRisk
# overallRisk
# governanceEpochDate
# compensationAsOfEpochDate
# maxAge
# priceHint
# previousClose
# open
# dayLow
# dayHigh
# regularMarketPreviousClose
# regularMarketOpen
# regularMarketDayLow
# regularMarketDayHigh
# beta
# forwardPE
# volume
# regularMarketVolume
# averageVolume
# averageVolume10days
# averageDailyVolume10Day
# bid
# ask
# bidSize
# askSize
# marketCap
# fiftyTwoWeekLow
# fiftyTwoWeekHigh
# priceToSalesTrailing12Months
# fiftyDayAverage
# twoHundredDayAverage
# currency
# enterpriseValue
# floatShares
# sharesOutstanding
# sharesShort
# sharesShortPriorMonth
# sharesShortPreviousMonthDate
# dateShortInterest
# sharesPercentSharesOut
# heldPercentInsiders
# heldPercentInstitutions
# shortRatio
# ...

# %% [markdown]
# #### 3. Identify <span style="color: #9467bd">__key trends in the market__</span>, including changes in <span style="color: #17becf">__consumer behavior__</span>, <span style="color: #2ca02c">__technological advancements__</span>, and <span style="color: #ff7f0e">__shifts in the competitive landscape__</span>.

# %% [markdown]
# ##### Electric Vehicle Market

# %%
url = 'https://www.mckinsey.com/industries/automotive-and-assembly/our-insights/'
response = requests.get('https://www.linkedin.com/pulse/electric-vehicle-market-growth-key-trends-analysis-forecast-modi-p3rjf')

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Extract the content from the response
    content = response.content

    # Parse the content with BeautifulSoup
    soup = BeautifulSoup(content, 'html.parser')

    # Find the article with class 'article-main'
    article = soup.find('article', class_='article-main')

    # Check if the article is found
    if article:
        # Extract the text from the article
        trends_text = article.get_text(strip=True)
        
        # Split the text into multiple lines based on newline characters
        trends_text_lines = trends_text.split('.')
        
        # Print each line separately
        for line in trends_text_lines:
            print(line.strip())  # Strip any leading or trailing whitespace
        
    else:
        print("Article not found.")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Electric Vehicle Market: Growth, Key Trends, Analysis and ForecastReport this articleHarshita ModiHarshita ModiSr
# SEO Manager at Sheer Analytics and Insights Private Limited| Approved as a DIPP startupPublished Nov 1, 2023+ FollowAccording to a market report, published bySheer Analytics and Insights,The globalelectric vehicle marketwas valued at $190
# 3 billion in 2021 and it is expected to reach $2300
# 9 billion at a CAGR of 23% between 2022 and 2032
# In recent years, the global electric vehicle (EV) market has experienced an electrifying surge in popularity, propelling it into the spotlight as a key player in the future of sustainable transportation
# As the world grapples with the pressing need to reduce greenhouse gas emissions and combat climate change, electric vehicles have emerged as a promising solution to usher in a greener and more environmentally friendly era of transportation
# ...

# %% [markdown]
# ##### Consumer Behavior

# %%
response = requests.get('https://www.linkedin.com/pulse/evolution-consumer-behavior-marketing-trends-stay-ahead/')

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Extract the content from the response
    content = response.content

    # Parse the content with BeautifulSoup
    soup = BeautifulSoup(content, 'html.parser')

    # Find the article with class 'article-main'
    article = soup.find('article', class_='article-main')

    # Check if the article is found
    if article:
        # Extract the text from the article
        trends_text = article.get_text(strip=True)
        
        # Split the text into multiple lines based on newline characters
        trends_text_lines = trends_text.split('.')
        
        # Print each line separately
        for line in trends_text_lines:
            print(line.strip())  # Strip any leading or trailing whitespace
        
    else:
        print("Article not found.")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# The Evolution of Consumer Behavior: Marketing Trends to Stay AheadReport this articleAttention GrabbersAttention GrabbersDominate LinkedIn with Our Proven Strategy and Expert Marketing Services
# Published Jul 27, 2023+ FollowIn today's dynamic marketplace, understanding consumer behavior is crucial for businesses to stay ahead of the competition
# Consumer behavior has undergone significant evolution, influenced by various factors such as technology, social media, and changing lifestyles
# In this blog post, we will explore the evolving landscape of consumer behavior and highlight key marketing trends that can help businesses adapt and thrive
# By reading this article, you will gain valuable insights into the latest consumer behavior trends, practical tips to engage with your target audience effectively, and strategies to stay ahead in the ever-changing marketing landscape
# ...

# %% [markdown]
# #### 4. Gather information on <span style="color: #d62728">__Canoo's financial performance__</span>, including its <span style="color: #1f77b4">__revenue__</span>, <span style="color: #e377c2">__profit margins__</span>, <span style="color: #7f7f7f">__return on investment__</span>, and <span style="color: #bcbd22">__expense structure__</span>.

# %%
import matplotlib.pyplot as plt

stock_history['Date'] = pd.to_datetime(stock_history['data'])

# Plotting
plt.figure(figsize=(6, 4))
plt.plot(stock_history['Date'], stock_history['Open'], label='Open Price', marker='o', )
plt.title('Stock Open and Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_2550/3963425073.py:3: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   stock_history['Date'] = pd.to_datetime(stock_history['data'])

# %%
pd.read_csv("canoo_financial_data.csv")
# Out:
#       Open   High    Low  Close    Volume  Dividends  Stock Splits
# 0    1.270  1.280  1.180  1.250   6111900        0.0           0.0
# 1    1.260  1.280  1.210  1.240   5432900        0.0           0.0
# 2    1.200  1.210  1.140  1.170   5614200        0.0           0.0
# 3    1.100  1.160  1.080  1.090   7369000        0.0           0.0
# 4    1.110  1.130  1.070  1.080  10109900        0.0           0.0
# ..     ...    ...    ...    ...       ...        ...           ...
# 245  0.242  0.249  0.237  0.237  41555100        0.0           0.0
# 246  0.239  0.240  0.228  0.234  39157600        0.0           0.0
# 247  0.232  0.247  0.232  0.247  32856000        0.0           0.0
# 248  0.245  0.272  0.245  0.263  53087500        0.0           0.0
# 249  0.268  0.271  0.254  0.257  31261000        0.0           0.0
#
# [250 rows x 7 columns]

# %%
data[['shortName','industry', 'shareHolderRightsRisk', 'marketCap','priceToSalesTrailing12Months', '52WeekChange', 'enterpriseToRevenue', 'totalRevenue']].head(1)
# Out:
#     shortName            industry  shareHolderRightsRisk  marketCap  \
# 0  Canoo Inc.  Auto Manufacturers                      7  149136480
#
#    priceToSalesTrailing12Months  52WeekChange  enterpriseToRevenue  \
# 0                     287.35352     -0.836994              423.954
#
#    totalRevenue
# 0        519000

# %%
data
# Out:
#                address1      city state    zip        country         phone  \
# 0  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 1  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 2  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 3  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 4  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 5  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 6  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
# 7  19951 Mariner Avenue  Torrance    CA  90503  United States  424 271 2144
#
#                  website            industry         industryKey  \
# 0  https://www.canoo.com  Auto Manufacturers  auto-manufacturers
# 1  https://www.canoo.com  Auto Manufacturers  auto-manufacturers
# 2  https://www.canoo.com  Auto Manufacturers  auto-manufacturers
# ...
